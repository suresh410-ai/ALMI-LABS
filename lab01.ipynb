# %% [markdown]
# ###Part 01:Lab Task is implement the following data structure
# 1. Lists
# 2. Arrays
# 3. Identify their types using type()
# 4. Perform mathematical operations on these datasets created-multiplication,division,poweroff
# 5. Combine text with Numpy function to generate a textual output-"Addition of two array1 +array2
# 6. Implement np.sin(),log(),log2(),np.exp())

# %%
import numpy as np
lst1=[1,2,3]
array1=np.array(lst1)
array1
# Out:
# array([1, 2, 3])

# %%
type(lst1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %% [markdown]
# **Perform Mathematical Operations on these datasets-Multiplication,Division**

# %%
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
print("array2 multiplied by array1:",array1*array2)
print("array2 division by array1:",array2/array1)
print("array2 raised to the power of array1:",array2**array1)
print(f"{array2}raised to the power of {array1}:,{array2**array1}")
# Out:
# array2 multiplied by array1: [3 4 3]
# array2 division by array1: [3.         1.         0.33333333]
# array2 raised to the power of array1: [3 4 1]
# [3 2 1]raised to the power of [1 2 3]:,[3 4 1]

# %%
people=['ann','brsndon','chen','David','emily','Farook']
age=[21,12,32,45,37,18]
weight=[55,35,77,68,70,60]
height=[160,135,170,165,168,105]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight,height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.ylabel("Weieght of Patients in Kgs")
plt.show()

# %%
plt.figure(figsize=(122,4))
plt.title("People's weight in kgs",fontsize=16,fontstyle='italic')

# Main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,
        color='orange',edgecolor='k',alpha=0.6)

plt.xlabel("people",fontsize=15)
#plt.xticks(fontsize=14,rotation=30)
#plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# Part-03:Access Data from various sources and formats

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_table("aiml.txt")

# %%
df1

# %%
data2=pd.read_csv("aiml.csv")

# %%
data2

# %%
data3 = pd.read_excel("aiml.xlxs")

# %% [markdown]
# Part-03:Access Data from various sources and formats
